# %%
import nltk

# %%
import pickle

# %%
from nltk.stem import WordNetLemmatizer
import json
lem = WordNetLemmatizer()

# %%
import random
import numpy as np

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

# %%
words =[]
documents= []
classes = []
ignore_words = ['!','?',':',';','.',',','-']

# %%
intents = open('intents.json').read()
images = open('images.json').read()
suggestions = open('suggestions.json').read()

# %%
intents = json.loads(intents)

# %%
images = json.loads(images)

# %%
suggestions = json.loads(suggestions)

# %%
import nltk
nltk.download('punkt')
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
import nltk
nltk.download('wordnet')
words = [lem.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training=[]

output_empty = [0]*len(classes)

for doc in documents:
    
    bag =[]
    
    pattern_words = doc[0] # list of tokenized words for each doc
    
    pattern_words = [lem.lemmatize(w.lower()) for w in pattern_words]
    
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] =1
    training.append([bag , output_row])

random.shuffle(training)
training  = np.array(training)
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-29-8899f1b6c4f6>:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training  = np.array(training)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu')) #input layer
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu')) #hidden layer with 64 neurons
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax')) #output layer number of neurons=intent

sgd = SGD(lr = 0.01, decay = 1e-6, momentum=0.9, nesterov=True) # learning rate = 0.01 
model.compile(loss='categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'])

#fitting and saving the model

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

model.save('chatbot_model.h5', hist)
# Out:
# Epoch 1/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.8847 - accuracy: 0.0373
# Epoch 2/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.8458 - accuracy: 0.0746
# Epoch 3/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.7238 - accuracy: 0.0970
# Epoch 4/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.5939 - accuracy: 0.1269
# Epoch 5/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.5605 - accuracy: 0.0896
# Epoch 6/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.4204 - accuracy: 0.1716
# Epoch 7/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.2563 - accuracy: 0.1493
# Epoch 8/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.1174 - accuracy: 0.2239
# Epoch 9/200
# 27/27 [==============================] - 0s 1ms/step - loss: 3.0296 - accuracy: 0.2313
# Epoch 10/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.8304 - accuracy: 0.2612
# Epoch 11/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.7256 - accuracy: 0.2687
# Epoch 12/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.6663 - accuracy: 0.3433
# Epoch 13/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.4325 - accuracy: 0.3955
# Epoch 14/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.1290 - accuracy: 0.4627
# Epoch 15/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.0851 - accuracy: 0.4328
# Epoch 16/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.0066 - accuracy: 0.4478
# Epoch 17/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.9953 - accuracy: 0.4925
# Epoch 18/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.9116 - accuracy: 0.5000
# Epoch 19/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.7887 - accuracy: 0.5299
# Epoch 20/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.7532 - accuracy: 0.5224
# Epoch 21/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.5246 - accuracy: 0.5821
# Epoch 22/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.5507 - accuracy: 0.5672
# Epoch 23/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.3756 - accuracy: 0.6194
# Epoch 24/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.3626 - accuracy: 0.6045
# Epoch 25/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.4504 - accuracy: 0.6194
# Epoch 26/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.1672 - accuracy: 0.6866
# Epoch 27/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.1901 - accuracy: 0.6866
# Epoch 28/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.1413 - accuracy: 0.7164
# Epoch 29/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.0901 - accuracy: 0.6791
# Epoch 30/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.0518 - accuracy: 0.7090
# Epoch 31/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.9221 - accuracy: 0.7687
# Epoch 32/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.9533 - accuracy: 0.7239
# Epoch 33/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8653 - accuracy: 0.7388
# Epoch 34/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.9357 - accuracy: 0.7313
# Epoch 35/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.9049 - accuracy: 0.7612
# Epoch 36/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8558 - accuracy: 0.7687
# Epoch 37/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8699 - accuracy: 0.7537
# Epoch 38/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8788 - accuracy: 0.7687
# Epoch 39/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.7379 - accuracy: 0.7761
# Epoch 40/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8018 - accuracy: 0.7537
# Epoch 41/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.7899 - accuracy: 0.7687
# Epoch 42/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.7519 - accuracy: 0.7687
# Epoch 43/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6239 - accuracy: 0.8507
# Epoch 44/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5112 - accuracy: 1.00 - 0s 1ms/step - loss: 0.6687 - accuracy: 0.8060
# Epoch 45/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.7481 - accuracy: 0.7836
# Epoch 46/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6663 - accuracy: 0.8209
# Epoch 47/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6328 - accuracy: 0.8134
# Epoch 48/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5543 - accuracy: 0.8657
# Epoch 49/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5929 - accuracy: 0.8358
# Epoch 50/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5983 - accuracy: 0.8433
# Epoch 51/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5973 - accuracy: 0.8209
# Epoch 52/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5158 - accuracy: 0.8657
# Epoch 53/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5520 - accuracy: 0.8284
# Epoch 54/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.8433
# Epoch 55/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5386 - accuracy: 0.8284
# Epoch 56/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3419 - accuracy: 0.9179
# Epoch 57/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6021 - accuracy: 0.8134
# Epoch 58/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4906 - accuracy: 0.8358
# Epoch 59/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5032 - accuracy: 0.8358
# Epoch 60/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4644 - accuracy: 0.8955
# Epoch 61/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6296 - accuracy: 0.8060
# Epoch 62/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4965 - accuracy: 0.8657
# Epoch 63/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4569 - accuracy: 0.8881
# Epoch 64/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3687 - accuracy: 0.9030
# Epoch 65/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4514 - accuracy: 0.8433
# Epoch 66/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4351 - accuracy: 0.8284
# Epoch 67/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4204 - accuracy: 0.8582
# Epoch 68/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8881
# Epoch 69/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4655 - accuracy: 0.8731
# Epoch 70/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.8582
# Epoch 71/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.8657
# Epoch 72/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4857 - accuracy: 0.8358
# Epoch 73/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4905 - accuracy: 0.8433
# Epoch 74/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4460 - accuracy: 0.8433
# Epoch 75/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4983 - accuracy: 0.8657
# Epoch 76/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8806
# Epoch 77/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8582
# Epoch 78/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.8731
# Epoch 79/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3118 - accuracy: 0.8881
# Epoch 80/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3429 - accuracy: 0.9254
# Epoch 81/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2362 - accuracy: 0.9478
# Epoch 82/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8955
# Epoch 83/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3250 - accuracy: 0.8806
# Epoch 84/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4498 - accuracy: 0.9030
# Epoch 85/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3177 - accuracy: 0.9179
# Epoch 86/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3310 - accuracy: 0.9104
# Epoch 87/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3921 - accuracy: 0.9104
# Epoch 88/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.9254
# Epoch 89/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3294 - accuracy: 0.8955
# Epoch 90/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1750 - accuracy: 0.9403
# Epoch 91/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3022 - accuracy: 0.9179
# Epoch 92/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3448 - accuracy: 0.8881
# Epoch 93/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2875 - accuracy: 0.8881
# Epoch 94/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8955
# Epoch 95/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8657
# Epoch 96/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3393 - accuracy: 0.9104
# Epoch 97/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2642 - accuracy: 0.9179
# Epoch 98/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2960 - accuracy: 0.9104
# Epoch 99/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2794 - accuracy: 0.9254
# Epoch 100/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2976 - accuracy: 0.9254
# Epoch 101/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2455 - accuracy: 0.9179
# Epoch 102/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.8881
# Epoch 103/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3788 - accuracy: 0.8955
# Epoch 104/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2807 - accuracy: 0.9030
# Epoch 105/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2866 - accuracy: 0.9030
# Epoch 106/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2460 - accuracy: 0.9254
# Epoch 107/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3112 - accuracy: 0.8955
# Epoch 108/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3428 - accuracy: 0.9030
# Epoch 109/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.8881
# Epoch 110/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2950 - accuracy: 0.9179
# Epoch 111/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1920 - accuracy: 0.9254
# Epoch 112/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3506 - accuracy: 0.8955
# Epoch 113/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2692 - accuracy: 0.9254
# Epoch 114/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.9478
# Epoch 115/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4278 - accuracy: 0.8507
# Epoch 116/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3455 - accuracy: 0.8582
# Epoch 117/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1878 - accuracy: 0.9254
# Epoch 118/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2220 - accuracy: 0.9179
# Epoch 119/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.9403
# Epoch 120/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.9328
# Epoch 121/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3695 - accuracy: 0.8806
# Epoch 122/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3742 - accuracy: 0.9104
# Epoch 123/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2319 - accuracy: 0.9478
# Epoch 124/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2033 - accuracy: 0.9328
# Epoch 125/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2797 - accuracy: 0.9254
# Epoch 126/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.9478
# Epoch 127/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1892 - accuracy: 0.9328
# Epoch 128/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.9104
# Epoch 129/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.9328
# Epoch 130/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.8657
# Epoch 131/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2533 - accuracy: 0.9328
# Epoch 132/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3093 - accuracy: 0.9030
# Epoch 133/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2624 - accuracy: 0.9254
# Epoch 134/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2374 - accuracy: 0.9328
# Epoch 135/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.9403
# Epoch 136/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 0.9254
# Epoch 137/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2840 - accuracy: 0.9254
# Epoch 138/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2144 - accuracy: 0.9328
# Epoch 139/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.9403
# Epoch 140/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2792 - accuracy: 0.9179
# Epoch 141/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9328
# Epoch 142/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1314 - accuracy: 0.9701
# Epoch 143/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2029 - accuracy: 0.9179
# Epoch 144/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2218 - accuracy: 0.9254
# Epoch 145/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3306 - accuracy: 0.8806
# Epoch 146/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9552
# Epoch 147/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2464 - accuracy: 0.9254
# Epoch 148/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.9403
# Epoch 149/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1853 - accuracy: 0.9403
# Epoch 150/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1926 - accuracy: 0.9328
# Epoch 151/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2799 - accuracy: 0.9030
# Epoch 152/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3132 - accuracy: 0.9104
# Epoch 153/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2931 - accuracy: 0.8955
# Epoch 154/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2626 - accuracy: 0.9104
# Epoch 155/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2029 - accuracy: 0.9552
# Epoch 156/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2473 - accuracy: 0.9328
# Epoch 157/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2221 - accuracy: 0.9179
# Epoch 158/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1919 - accuracy: 0.9552
# Epoch 159/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2227 - accuracy: 0.9254
# Epoch 160/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2004 - accuracy: 0.9104
# Epoch 161/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2850 - accuracy: 0.8955
# Epoch 162/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2509 - accuracy: 0.9328
# Epoch 163/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2450 - accuracy: 0.9403
# Epoch 164/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1828 - accuracy: 0.9403
# Epoch 165/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2143 - accuracy: 0.9179
# Epoch 166/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2696 - accuracy: 0.9328
# Epoch 167/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2839 - accuracy: 0.8955
# Epoch 168/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2567 - accuracy: 0.9104
# Epoch 169/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9104
# Epoch 170/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9552
# Epoch 171/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2625 - accuracy: 0.9104
# Epoch 172/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1888 - accuracy: 0.9254
# Epoch 173/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1016 - accuracy: 0.9776
# Epoch 174/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.9254
# Epoch 175/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2194 - accuracy: 0.9030
# Epoch 176/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1841 - accuracy: 0.9328
# Epoch 177/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2728 - accuracy: 0.9179
# Epoch 178/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1524 - accuracy: 0.9403
# Epoch 179/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1743 - accuracy: 0.9552
# Epoch 180/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.9328
# Epoch 181/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1015 - accuracy: 0.9776
# Epoch 182/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1970 - accuracy: 0.9552
# Epoch 183/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2630 - accuracy: 0.9328
# Epoch 184/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2317 - accuracy: 0.9179
# Epoch 185/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3031 - accuracy: 0.8955
# Epoch 186/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2141 - accuracy: 0.9179
# Epoch 187/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1600 - accuracy: 0.9552
# Epoch 188/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0967 - accuracy: 0.9851
# Epoch 189/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2227 - accuracy: 0.9328
# Epoch 190/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2952 - accuracy: 0.8806
# Epoch 191/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2096 - accuracy: 0.9254
# Epoch 192/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1361 - accuracy: 0.9552
# Epoch 193/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1650 - accuracy: 0.9627
# Epoch 194/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1790 - accuracy: 0.9254
# Epoch 195/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2481 - accuracy: 0.9328
# Epoch 196/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.9403
# Epoch 197/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9552
# Epoch 198/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1520 - accuracy: 0.9478
# Epoch 199/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2559 - accuracy: 0.9179
# Epoch 200/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9478

# %%
from keras.models import load_model

# %%
model = load_model('chatbot_model.h5')

# %%
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl','rb'))

classes = pickle.load(open('classes.pkl','rb'))

# %%
def cleanup_sent(sentence):
    sen_words =  nltk.word_tokenize(sentence)
    sen_words = [lem.lemmatize(word.lower()) for word in sen_words]
    return sen_words

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sen_words = cleanup_sent(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sen_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    PROB_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>PROB_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def getImage(ints, images_json):
    list_images = images_json['intents']
    tag = ints[0]['intent']
    for i in list_images:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            return result
    return ("-1")
def getSuggest(ints, sugg_json):
    tag = ints[0]['intent']
    list_sugg = sugg_json['intents']
    for i in list_sugg:
        if(i['tag']== tag):
            result = i['responses']
            return result
    return("-1")
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    img = getImage(ints, images)
    sugg = getSuggest(ints,suggestions)
    answer=[]
    answer.append(res)
    if img!='-1':
        answer.append(img)
    else:
        answer.append("-1")
    if sugg!='-1':
        answer.append(sugg)
    else:
        answer.append("-1")
    return answer

# %%
import tkinter
from tkinter import *
from PIL import Image,ImageTk

# %%
def fb():
    window = Toplevel(base)
    window.title("Feedback")
    window.geometry("200x200")
    var='0'
    #var.set(0)
    r1 = Radiobutton(window, text='1 Star ', variable=var, value='1', background = "light blue",command=window.destroy,tristatevalue=0)
    r1.pack(side = TOP, ipady = 5) 
    r2 = Radiobutton(window, text='2 Stars', variable=var, value='2',background = "light blue", command=window.destroy,tristatevalue=0)
    r2.pack(side = TOP, ipady = 5) 
    r3 = Radiobutton(window, text='3 Stars', variable=var, value='3', background = "light blue",command=window.destroy,tristatevalue=0)
    r3.pack(side = TOP, ipady = 5) 
    r4 = Radiobutton(window, text='4 Stars', variable=var, value='4', background = "light blue",command=window.destroy,tristatevalue=0)
    r4.pack(side = TOP, ipady = 5) 
    r5= Radiobutton(window, text='5 Stars', variable=var, value='5', background = "light blue",command=window.destroy,tristatevalue=0)
    r5.pack(side = TOP, ipady = 5) 
    ChatLog.config(state = NORMAL)
        
    return var

# %%
def printfb(var):
    ChatLog.insert(END, "Jarvis:Thank you for your feedback!\n\n")
    ChatLog.config(state=DISABLED)
    ChatLog.yview(END)

# %%
global img

def send():
    
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state = NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 14, 'bold' ))
        
        answer = chatbot_response(msg)
        res=answer[0]
        ChatLog.insert(END, "Jarvis: " + res + '\n\n')
        if answer[1]!='-1':
            ChatLog.insert(END, "Jarvis: ")
            result = answer[1]
            img=Image.open(result)
            img=img.resize((300,300),Image.ANTIALIAS)
            img=ImageTk.PhotoImage(img)
            ChatLog.image=img
            ChatLog.image_create(INSERT, image=img)
        if answer[2]!='-1':
            #for i in answer[2]:
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][0], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][0])) ) 
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][1], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][1])) )
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][2], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][2])) )
            
        ChatLog.insert(END, "\n\n")
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
def suggsend(i):
    ChatLog.config(state = NORMAL)
    ChatLog.config(foreground="#442265", font=("Verdana", 16,'bold'))
    answer = chatbot_response(i)
    res=answer[0]
    ChatLog.insert(END, "Jarvis: " + res + '\n')
    
base = Tk()
base.title("Welcome to Customer Care")
base.geometry("700x500")
base.resizable(width=FALSE, height=FALSE)
    
ChatLog = Text(base, bd=0, bg="#FAF5A8", height="8", width="50", font=("Arial",16,'bold'))
        
ChatLog.config(state =  DISABLED)
    
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
    
SendButton = Button(base, font=("Comic Sans MS",14,'bold'), text="SEND", width="12", height=5,
                    bd=0, bg="#3cd548", activebackground="#3c9d9b",fg='#ffffff',
                    command=send )
 
    #Create the box to enter message

EntryBox = Text(base, bd=0, bg="#FAF5A8",width="29", height="5", font=("Arial",14))
  
scrollbar.place(x=600,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=599)
EntryBox.place(x=6, y=401, height=70, width=350)
SendButton.place(x=370, y=410, height=50,width=150)
fbButton = Button(base, font=("Verdana",12,'bold'), text="Feedback", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command=lambda:printfb(fb()))

fbButton.place(x=6, y=350, height=40) 
base.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\asus\anaconda3\envs\project1\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-42-4acbb98d9da6>", line 12, in send
#     answer = chatbot_response(msg)
#   File "<ipython-input-37-d9995acf1d30>", line 27, in chatbot_response
#     res = getResponse(ints, intents)
#   File "<ipython-input-37-d9995acf1d30>", line 2, in getResponse
#     tag = ints[0]['intent']
# IndexError: list index out of range
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\asus\anaconda3\envs\project1\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-42-4acbb98d9da6>", line 18, in send
#     img=Image.open(result)
#   File "C:\Users\asus\anaconda3\envs\project1\lib\site-packages\PIL\Image.py", line 2891, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'sale2.png'
